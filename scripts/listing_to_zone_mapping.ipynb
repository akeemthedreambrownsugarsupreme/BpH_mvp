# %% [markdown]
# This notebook aims to update the commercial and residential listings in accordance with their respective zones from the city zone map.

# %%
# !pip install shapely
# Out:
# DEPRECATION: Loading egg at /Users/habib/miniconda3/envs/pytorch_m1_3.11/lib/python3.11/site-packages/huggingface_hub-0.20.3-py3.8.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: shapely in /Users/habib/miniconda3/envs/pytorch_m1_3.11/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: numpy<2,>=1.14 in /Users/habib/miniconda3/envs/pytorch_m1_3.11/lib/python3.11/site-packages (from shapely) (1.26.4)

# %%
# print the zonal map data
import pandas as pd
import numpy as np
from shapely.geometry import MultiPolygon, Point
from shapely.wkt import loads as load_wkt

# read the data
zonal_data = pd.read_csv('../data/Zoning_Bylaw_Geographical_Data_20240528.csv')

# print the data
print(zonal_data.head(5))
# Out:
#        id  zoning               description    date_ext  \
# 0  169754      PS        Parks and Services  2024/05/27
# 1  175633      CN  Neighbourhood Commercial  2024/05/27
# 2  170985      CG        General Commercial  2024/05/27
# 3  176327  RM h16  Medium Scale Residential  2024/05/27
# 4  176677  RM h16  Medium Scale Residential  2024/05/27
#
#                                                  url  \
# 0  http://webdocs.edmonton.ca/InfraPlan/zoningbyl...
# 1  http://webdocs.edmonton.ca/InfraPlan/zoningbyl...
# 2  http://webdocs.edmonton.ca/InfraPlan/zoningbyl...
# 3  http://webdocs.edmonton.ca/InfraPlan/zoningbyl...
# 4  http://webdocs.edmonton.ca/InfraPlan/zoningbyl...
#
#                                geometry_multipolygon
# 0  MULTIPOLYGON (((-113.46405030242478 53.4139561...
# 1  MULTIPOLYGON (((-113.48544480430161 53.5005298...
# 2  MULTIPOLYGON (((-113.41637166582207 53.5855382...
# 3  MULTIPOLYGON (((-113.49564121741932 53.5688278...
# 4  MULTIPOLYGON (((-113.37718667032956 53.4474629...

# %%
# Function to check if a point lies within a multipolygon
def is_point_in_multipolygon(lat, lon):
    point = Point(lon, lat)  # Note: Shapely uses (lon, lat) order
    for _, row in zonal_data.iterrows():
        multipolygon_wkt = row['geometry_multipolygon']
        multipolygon = load_wkt(multipolygon_wkt)
        if multipolygon.contains(point):
            # return as row as json
            return row.to_dict()
    return {}

# Test the function with an example point
lat = 53.5005
lon = -113.4855

print({'lat': lat, 'lon': lon, 'zoning': is_point_in_multipolygon(lat, lon)})
# Out:
# {'lat': 53.5005, 'lon': -113.4855, 'zoning': {'id': 175633, 'zoning': 'CN', 'description': 'Neighbourhood Commercial', 'date_ext': '2024/05/27', 'url': 'http://webdocs.edmonton.ca/InfraPlan/zoningbylaw/bylaw_12800.htm', 'geometry_multipolygon': 'MULTIPOLYGON (((-113.48544480430161 53.500529804717324, -113.48575021281256 53.50071076505371, -113.48624647281675 53.50100695034535, -113.4862309463645 53.49987387916919, -113.48469211617721 53.49987363830927, -113.48469421839806 53.50005511947766, -113.4846925282687 53.50040641492085, -113.4852351676 53.50040558977945, -113.48544480430161 53.500529804717324)))'}}

# %%
# read the {} data and find its zone and update the data
# residential datas are in json format and in ../data/{}}/ folder they are slplited into multiple .js files

import pandas as pd

def update_zoning(listing_type):
    import json
    import os

    for file in os.listdir(f'../data/{listing_type}/'):
        with open(f'../data/{listing_type}/' + file) as f:
            data = json.load(f)
            listings = data['Results']
            
            for listing in listings:
                lat = listing['Property']['Address']['Latitude']
                lon = listing['Property']['Address']['Longitude']
                
                # Find the zoning for the listing
                zone = is_point_in_multipolygon(lat, lon)
                listing['zone'] = zone
                
                # append listing to a dataframe as a row
                df = pd.DataFrame([listing])
                
            
            # Save the updated data with _mapped suffix in the filename
            with open(f'../data/{listing_type}/' + file.replace('.js', '_zone_mapped.js'), 'w') as newfile:
                json.dump(data, newfile)
                newfile.close()
            
            f.close()
            
# Update the zoning for residential and commercial listings
update_zoning('residential')
update_zoning('commercial')

# %%
# !pip install ace_tools
# Out:
# DEPRECATION: Loading egg at /Users/habib/miniconda3/envs/pytorch_m1_3.11/lib/python3.11/site-packages/huggingface_hub-0.20.3-py3.8.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: Could not find a version that satisfies the requirement ace_tools (from versions: none)
# ERROR: No matching distribution found for ace_tools

# %%
import pandas as pd
import json
import os

def update_zoning(listing_type):
    all_listings = []
    
    for file in os.listdir(f'../data/{listing_type}/'):
        if '_zone_mapped' in file:
            with open(f'../data/{listing_type}/' + file) as f:
                data = json.load(f)
                listings = data['Results']
                
                for listing in listings:
                    # add a listing type
                    listing['listing_type'] = listing_type
                    # Append listing to the all_listings list
                    all_listings.append(listing)
                
    # Create a DataFrame from all listings
    df = pd.DataFrame(all_listings)
    return df

# Update the zoning for residential and commercial listings
df_residential = update_zoning('residential')
df_commercial = update_zoning('commercial')

# Optionally, combine both dataframes into one
df_all = pd.concat([df_residential, df_commercial], ignore_index=True)

print(df_all.head(5))

# print the first first row as json
print(df_all.iloc[0].to_json())

# print the last row as json
print(df_all.iloc[-1].to_json())
# Out:
#          Id MlsNumber                                      PublicRemarks  \
# 0  26804622  E4384032  INVESTOR ALERT! Cheerful bungalow nestled in p...
# 1  26828866  E4384868  Fantastic condo located in sought-after Belgra...
# 2  26860468  E4386037  Beautiful bungalow home for sale in the desira...
# 3  26665069  E4378735  Stunning, RIVER FACING, LARGE SIZED parcel of ...
# 4  26539335  E4373981  Welcome to the community of Northmount! This u...
#
#                                             Building  \
# 0  {'BathroomTotal': '3', 'Bedrooms': '3', 'SizeI...
# 1  {'BathroomTotal': '2', 'Bedrooms': '3', 'SizeI...
# 2  {'BathroomTotal': '2', 'Bedrooms': '5', 'SizeI...
# 3  {'Bedrooms': '0', 'StoriesTotal': '', 'Type': ...
# 4  {'BathroomTotal': '4', 'Bedrooms': '5', 'SizeI...
#
#                                           Individual  \
# 0  [{'IndividualID': 2094464, 'Name': 'Samar Rang...
# 1  [{'IndividualID': 2070038, 'Name': 'Dave Cousi...
# 2  [{'IndividualID': 1999896, 'Name': 'Rishi Ghai...
# 3  [{'IndividualID': 1999896, 'Name': 'Rishi Ghai...
# 4  [{'IndividualID': 1992068, 'Name': 'Jackson Ho...
#
#                                             Property Business  \
# 0  {'Price': '$399,000', 'Type': 'Single Family',...       {}
# 1  {'Price': '$399,000', 'Type': 'Single Family',...       {}
# 2  {'Price': '$399,000', 'Type': 'Single Family',...       {}
# 3  {'Price': '$399,000', 'Type': 'Vacant Land', '...       {}
# 4  {'Price': '$399,000', 'Type': 'Single Family',...       {}
#
#                          Land  \
# 0                          {}
# 1   {'SizeTotal': '73.78 m2'}
# 2  {'SizeTotal': '590.31 m2'}
# 3  {'SizeTotal': '796.15 m2'}
# 4  {'SizeTotal': '608.43 m2'}
#
#                                         AlternateURL PostalCode  ...  \
# 0  {'VideoLink': 'https://youriguide.com/28j16_84...     T5T0C7  ...
# 1                                                NaN     T6G1S5  ...
# 2                                                NaN     T5R4G7  ...
# 3                                                NaN     T5Y3Z6  ...
# 4  {'VideoLink': 'https://www.asteroom.com/pviewe...     T5E1Y5  ...
#
#    OpenHouse OpenHouseInsertDateUTC ListingTimeZone ListingBoundary  \
# 0        NaN                    NaN             NaN             NaN
# 1        NaN                    NaN             NaN             NaN
# 2        NaN                    NaN             NaN             NaN
# 3        NaN                    NaN             NaN             NaN
# 4        NaN                    NaN             NaN             NaN
#
#   ListingGMT HasNewImageUpdate PriceChangeDateUTC HasOpenHouseUpdate  \
# 0        NaN               NaN                NaN                NaN
# 1        NaN               NaN                NaN                NaN
# 2        NaN               NaN                NaN                NaN
# 3        NaN               NaN                NaN                NaN
# 4        NaN               NaN                NaN                NaN
#
#   HasPriceUpdate StandardStatusId
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
#
# [5 rows x 35 columns]
# {"Id":"26804622","MlsNumber":"E4384032","PublicRemarks":"INVESTOR ALERT! Cheerful bungalow nestled in prime location.Walking distance to West Edmonton Mall & 10km to downtown Edmonton.  3 + 1 Bedroom and 2.5 Bathrooms. Main Floor Extended ceilings, 3 Bedroom finish the main floor, basement partially finished  with bedroom and 3 piece bathroom. 8000 square feet private lot from patio door access- 60 ft wide by 130 ft deep. Great investment opportunity for infill or building multiplex. Only fridge is the only appliance included.  NOTE: Foundation issues with south wall & driveway repairs. Quote available from 2022 with reputable foundation repair company. - Buyer needs to accept Title insurance in lieu of RPR with compliance. - Property Sold as is - where is , with no Warranties or representations. (31188654)","Building":{"BathroomTotal":"3","Bedrooms":"3","SizeInterior":"100.73 m2","StoriesTotal":"1","Type":"House","FloorAreaMeasurements":[{"Area":"1084 sqft","AreaUnformatted":"1084 sqft","Type":"Square Footage","Source":"","MeasureUnitId":"1","TypeId":"1","SourceId":"0","SortBy":"1"}]},"Individual":[{"IndividualID":2094464,"Name":"Samar Rangra","Organization":{"OrganizationID":283363,"Name":"Exp Realty","Logo":"https:\/\/cdn.realtor.ca\/organization\/en-CA\/TS638488683000000000\/lowres\/1336702.jpg","Address":{"AddressText":"1400-10665 Jasper Ave NW|Edmonton, Alberta T5J3S9","PermitShowAddress":true},"Phones":[{"PhoneType":"Telephone","PhoneNumber":"262-7653","AreaCode":"403","PhoneTypeId":"1"}],"Emails":[{"ContactId":"551148717"}],"OrganizationType":"Firm","HasEmail":true,"PermitFreetextEmail":true,"PermitShowListingLink":true,"RelativeDetailsURL":"\/office\/firm\/283363\/exp-realty-1400-10665-jasper-ave-nw-edmonton-alberta-t5j3s9","PhotoLastupdate":"2024-04-16 12:45:00 PM"},"Phones":[{"PhoneType":"Telephone","PhoneNumber":"904-9859","AreaCode":"780","PhoneTypeId":"1"}],"Emails":[{"ContactId":"537233770"}],"Photo":"https:\/\/cdn.realtor.ca\/individual\/TS637330528200000000\/lowres\/1366928.jpg","Position":"Associate","PermitFreetextEmail":true,"FirstName":"Samar","LastName":"Rangra","CorporationDisplayTypeId":"0","PermitShowListingLink":true,"RelativeDetailsURL":"\/agent\/2094464\/samar-rangra-1400-10665-jasper-ave-nw-edmonton-alberta-t5j3s9","AgentPhotoLastUpdated":"2020-08-15 01:47:00","PhotoHighRes":"https:\/\/cdn.realtor.ca\/individual\/TS637330528200000000\/highres\/1366928.jpg","RankMyAgentKey":"","RealSatisfiedKey":"","TestimonialTreeKey":""}],"Property":{"Price":"$399,000","Type":"Single Family","Address":{"AddressText":"8407 171 ST NW NW|Edmonton, Alberta T5T0C7","Longitude":"-113.6164052","Latitude":"53.5173615338435","PermitShowAddress":true},"Photo":[{"SequenceId":"1","HighResPath":"https:\/\/cdn.realtor.ca\/listings\/TS638496892099570000\/reb10\/highres\/2\/E4384032_1.jpg","MedResPath":"https:\/\/cdn.realtor.ca\/listings\/TS638496892099570000\/reb10\/medres\/2\/E4384032_1.jpg","LowResPath":"https:\/\/cdn.realtor.ca\/listings\/TS638496892099570000\/reb10\/lowres\/2\/E4384032_1.jpg","LastUpdated":"2024-04-26 12:46:49 AM","TypeId":"0"}],"Parking":[{"Name":"Oversize"},{"Name":"Detached Garage"}],"TypeId":"300","OwnershipType":"Freehold","AmmenitiesNearBy":"Playground, Public Transit, Schools, Shopping","OwnershipTypeGroupIds":[1],"ParkingType":"Oversize, Detached Garage","PriceUnformattedValue":"399000"},"Business":{},"Land":{},"AlternateURL":{"VideoLink":"https:\/\/youriguide.com\/28j16_8407_171_st_nw_edmonton_ab"},"PostalCode":"T5T0C7","HistoricalDataIsCleared":false,"ProvinceName":"Alberta","RelativeDetailsURL":"\/real-estate\/26804622\/8407-171-st-nw-nw-edmonton-thorncliffeedmo","StatusId":"1","PhotoChangeDateUTC":"2024-04-26 4:46:49 AM","Distance":"","RelativeURLEn":"\/real-estate\/26804622\/8407-171-st-nw-nw-edmonton-thorncliffeedmo","RelativeURLFr":"\/immobilier\/26804622\/8407-171-st-nw-nw-edmonton","Media":[{"MediaCategoryId":"2","MediaCategoryURL":"https:\/\/youriguide.com\/28j16_8407_171_st_nw_edmonton_ab" ...
# {"Id":"26091302","MlsNumber":"E4359395","PublicRemarks":"Welcome to the highly desired neighbourhood of Terrace Heights. With being steps away from Edmontons famous river valley and tons of amenities including one of Edmontons newest libraries, Bonnie Doon mall, and Argyll Learning centre this is a perfect opportunity for any investor or home owner looking to build their new home in the core of Edmonton.   30 X 120' (30450697)","Building":{"Bedrooms":"0","StoriesTotal":"","Type":"No Building"},"Individual":[{"IndividualID":2132214,"Name":"Cameron Dembinsky","Organization":{"OrganizationID":67034,"Name":"RE\/MAX Real Estate","Logo":"https:\/\/cdn.realtor.ca\/organization\/en-CA\/TS638072403600000000\/lowres\/1004794.jpg","Address":{"AddressText":"9909 103 St|Fort Saskatchewan, Alberta T8L2C8","PermitShowAddress":true},"Phones":[{"PhoneType":"Telephone","PhoneNumber":"998-2295","AreaCode":"780","PhoneTypeId":"1"},{"PhoneType":"Fax","PhoneNumber":"998-0344","AreaCode":"780","PhoneTypeId":"4"}],"Emails":[{"ContactId":"509231056"}],"OrganizationType":"Firm","HasEmail":true,"PermitFreetextEmail":true,"PermitShowListingLink":true,"RelativeDetailsURL":"\/office\/firm\/67034\/remax-real-estate-9909-103-st-fort-saskatchewan-alberta-t8l2c8","PhotoLastupdate":"2022-12-21 5:26:00 PM"},"Phones":[{"PhoneType":"Telephone","PhoneNumber":"217-0432","AreaCode":"780","PhoneTypeId":"1"},{"PhoneType":"Fax","PhoneNumber":"998-0344","AreaCode":"780","PhoneTypeId":"4"}],"Emails":[{"ContactId":"509121860"}],"Photo":"https:\/\/cdn.realtor.ca\/individual\/TS638375665200000000\/lowres\/1384928.jpg","Position":"Associate","PermitFreetextEmail":true,"FirstName":"Cameron","LastName":"Dembinsky","CorporationDisplayTypeId":"0","PermitShowListingLink":true,"RelativeDetailsURL":"\/agent\/2132214\/cameron-dembinsky-9909-103-st-fort-saskatchewan-alberta-t8l2c8","AgentPhotoLastUpdated":"2023-12-07 17:22:00","PhotoHighRes":"https:\/\/cdn.realtor.ca\/individual\/TS638375665200000000\/highres\/1384928.jpg","RankMyAgentKey":"","RealSatisfiedKey":"","TestimonialTreeKey":""},{"IndividualID":1947182,"Name":"Thomas J. Lowe","Organization":{"OrganizationID":67034,"Name":"RE\/MAX Real Estate","Logo":"https:\/\/cdn.realtor.ca\/organization\/en-CA\/TS638072403600000000\/lowres\/1004794.jpg","Address":{"AddressText":"9909 103 St|Fort Saskatchewan, Alberta T8L2C8","PermitShowAddress":true},"Phones":[{"PhoneType":"Telephone","PhoneNumber":"998-2295","AreaCode":"780","PhoneTypeId":"1"},{"PhoneType":"Fax","PhoneNumber":"998-0344","AreaCode":"780","PhoneTypeId":"4"}],"Emails":[{"ContactId":"509231056"}],"OrganizationType":"Firm","HasEmail":true,"PermitFreetextEmail":true,"PermitShowListingLink":true,"RelativeDetailsURL":"\/office\/firm\/67034\/remax-real-estate-9909-103-st-fort-saskatchewan-alberta-t8l2c8","PhotoLastupdate":"2022-12-21 5:26:00 PM"},"Phones":[{"PhoneType":"Telephone","PhoneNumber":"966-3234","AreaCode":"780","PhoneTypeId":"1"},{"PhoneType":"Fax","PhoneNumber":"998-0344","AreaCode":"780","PhoneTypeId":"4"}],"Websites":[{"Website":"http:\/\/www.tomlowe.ca\/","WebsiteTypeId":"1"},{"Website":"https:\/\/www.facebook.com\/tomlowerealestate","WebsiteTypeId":"2"},{"Website":"https:\/\/www.instagram.com\/loweandcorealestate\/","WebsiteTypeId":"5"}],"Emails":[{"ContactId":"530999203"}],"Photo":"https:\/\/cdn.realtor.ca\/individual\/TS638418966000000000\/lowres\/1242061.jpg","Position":"Associate","PermitFreetextEmail":true,"FirstName":"Thomas","LastName":"Lowe","CorporationDisplayTypeId":"0","PermitShowListingLink":true,"RelativeDetailsURL":"\/agent\/1947182\/thomas-lowe-9909-103-st-fort-saskatchewan-alberta-t8l2c8","AgentPhotoLastUpdated":"2024-01-26 20:10:00","PhotoHighRes":"https:\/\/cdn.realtor.ca\/individual\/TS638418966000000000\/highres\/1242061.jpg","RankMyAgentKey":"","RealSatisfiedKey":"","TestimonialTreeKey":""}],"Property":{"Price":"$224,000","Type":"Vacant Land","Address":{"AddressText":"9909 68 ST NW|Edmonton, Alberta T8H0H9","Longitude":"-113.4334486","Latitude" ...

# %%
import pandas as pd
import json
import os

def extract_listing_info(listing, listing_type):
    # Extract the necessary fields from the listing, handling missing values
    return {
        "price": listing["Property"].get("Price", ""),
        "type": listing["Property"].get("Type", ""),
        "address": listing["Property"]["Address"].get("AddressText", ""),
        "latitude": listing["Property"]["Address"].get("Latitude", ""),
        "longitude": listing["Property"]["Address"].get("Longitude", ""),
        "zone": [
            {
                "code": listing["zone"].get("zoning", "") if "zone" in listing else "",
                "description": listing["zone"].get("description", "") if "zone" in listing else ""
            }
        ],
        "photos": [photo.get("HighResPath", "") for photo in listing["Property"].get("Photo", [])],
        "parking": [parking.get("Name", "") for parking in listing["Property"].get("Parking", [])],
        "amenities_nearby": listing["Property"].get("AmmenitiesNearBy", "").split(", ") if listing["Property"].get("AmmenitiesNearBy") else [],
        "bedrooms": listing["Building"].get("Bedrooms", ""),
        "bathrooms": listing["Building"].get("BathroomTotal", ""),
        "size_interior": listing["Building"].get("SizeInterior", ""),
        "ownership_type": listing["Property"].get("OwnershipType", ""),
        "public_remarks": listing.get("PublicRemarks", ""),
        "postal_code": listing.get("PostalCode", ""),
        "historical_data": {
            "price_change_date": listing.get("PriceChangeDateUTC", ""),
            "photo_change_date": listing.get("PhotoChangeDateUTC", "")
        },
        "additional_features": listing.get("AdditionalFeatures", []),
        "listing_type": listing_type
    }

def update_zoning(listing_type):
    all_listings = []
    
    for file in os.listdir(f'../data/{listing_type}/'):
        if '_zone_mapped' in file:
            with open(f'../data/{listing_type}/' + file) as f:
                data = json.load(f)
                listings = data['Results']
                
                for listing in listings:
                    extracted_info = extract_listing_info(listing, listing_type)
                    all_listings.append(extracted_info)
                
    # Create a DataFrame from all listings
    df = pd.DataFrame(all_listings)
    return df

# Update the zoning for residential and commercial listings
df_residential = update_zoning('residential')
df_commercial = update_zoning('commercial')

# Optionally, combine both dataframes into one
df_all = pd.concat([df_residential, df_commercial], ignore_index=True)

# Display the dataframe to the user
# import ace_tools as tools; tools.display_dataframe_to_user(name="All Listings", dataframe=df_all)

print(df_all.head(5))

# Print the first row as JSON
print(df_all.iloc[0].to_json())

# save the data to a csv file
df_all.to_csv('../data/features.csv', index=False)

# save the data to a json file
df_all.to_json('../data/features.json', orient='records')
# Out:
#       price           type                                       address  \
# 0  $399,000  Single Family    8407 171 ST NW NW|Edmonton, Alberta T5T0C7
# 1  $399,000  Single Family  #210 7327 118 ST NW|Edmonton, Alberta T6G1S5
# 2  $399,000  Single Family       15717 87 AV NW|Edmonton, Alberta T5R4G7
# 3  $399,000    Vacant Land       1115 147 AV NW|Edmonton, Alberta T5Y3Z6
# 4  $399,000  Single Family       9116 137 AV NW|Edmonton, Alberta T5E1Y5
#
#            latitude          longitude  \
# 0  53.5173615338435       -113.6164052
# 1        53.5096593  -113.534278415344
# 2  53.5190815534664  -113.593025884656
# 3  53.6100590786087         -113.36007
# 4   53.599921200001       -113.4829512
#
#                                                 zone  \
# 0  [{'code': 'RS', 'description': 'Small Scale Re...
# 1  [{'code': 'RM h16', 'description': 'Medium Sca...
# 2  [{'code': 'RS', 'description': 'Small Scale Re...
# 3  [{'code': 'RS', 'description': 'Small Scale Re...
# 4  [{'code': 'RS', 'description': 'Small Scale Re...
#
#                                               photos  \
# 0  [https://cdn.realtor.ca/listings/TS63849689209...
# 1  [https://cdn.realtor.ca/listings/TS63850171644...
# 2  [https://cdn.realtor.ca/listings/TS63850717242...
# 3  [https://cdn.realtor.ca/listings/TS63846982012...
# 4  [https://cdn.realtor.ca/listings/TS63844195605...
#
#                         parking  \
# 0   [Oversize, Detached Garage]
# 1  [Heated Garage, Underground]
# 2             [Detached Garage]
# 3                            []
# 4             [Detached Garage]
#
#                                     amenities_nearby bedrooms bathrooms  \
# 0    [Playground, Public Transit, Schools, Shopping]        3         3
# 1                                   [Public Transit]        3         2
# 2  [Golf Course, Playground, Public Transit, Scho...        5         2
# 3                   [Golf Course, Schools, Shopping]        0
# 4    [Playground, Public Transit, Schools, Shopping]        5         4
#
#   size_interior      ownership_type  \
# 0     100.73 m2            Freehold
# 1     125.84 m2  Condominium/Strata
# 2      97.96 m2            Freehold
# 3                          Freehold
# 4      258.3 m2            Freehold
#
#                                       public_remarks postal_code  \
# 0  INVESTOR ALERT! Cheerful bungalow nestled in p...      T5T0C7
# 1  Fantastic condo located in sought-after Belgra...      T6G1S5
# 2  Beautiful bungalow home for sale in the desira...      T5R4G7
# 3  Stunning, RIVER FACING, LARGE SIZED parcel of ...      T5Y3Z6
# 4  Welcome to the community of Northmount! This u...      T5E1Y5
#
#                                      historical_data additional_features  \
# 0  {'price_change_date': '', 'photo_change_date':...                  []
# 1  {'price_change_date': '', 'photo_change_date':...                  []
# 2  {'price_change_date': '', 'photo_change_date':...                  []
# 3  {'price_change_date': '', 'photo_change_date':...                  []
# 4  {'price_change_date': '', 'photo_change_date':...                  []
#
#   listing_type
# 0  residential
# 1  residential
# 2  residential
# 3  residential
# 4  residential
# {"price":"$399,000","type":"Single Family","address":"8407 171 ST NW NW|Edmonton, Alberta T5T0C7","latitude":"53.5173615338435","longitude":"-113.6164052","zone":[{"code":"RS","description":"Small Scale Residential"}],"photos":["https:\/\/cdn.realtor.ca\/listings\/TS638496892099570000\/reb10\/highres\/2\/E4384032_1.jpg"],"parking":["Oversize","Detached Garage"],"amenities_nearby":["Playground","Public Transit","Schools","Shopping"],"bedrooms":"3","bathrooms":"3","size_interior":"100.73 m2","ownership_type":"Freehold","public_remarks":"INVESTOR ALERT! Cheerful bungalow nestled in prime location.Walking distance to West Edmonton Mall & 10km to downtown Edmonton.  3 + 1 Bedroom and 2.5 Bathrooms. Main Floor Extended ceilings, 3 Bedroom finish the main floor, basement partially finished  with bedroom and 3 piece bathroom. 8000 square feet private lot from patio door access- 60 ft wide by 130 ft deep. Great investment opportunity for infill or building multiplex. Only fridge is the only appliance included.  NOTE: Foundation issues with south wall & driveway repairs. Quote available from 2022 with reputable foundation repair company. - Buyer needs to accept Title insurance in lieu of RPR with compliance. - Property Sold as is - where is , with no Warranties or representations. (31188654)","postal_code":"T5T0C7","historical_data":{"price_change_date":"","photo_change_date":"2024-04-26 4:46:49 AM"},"additional_features":[],"listing_type":"residential"}
